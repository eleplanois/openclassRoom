# %% [markdown]
# # Import données

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
EdStatsData=pd.read_csv("EdStatsData.csv")
EdStatsSeries=pd.read_csv("EdStatsSeries.csv")
EdStatsCountry=pd.read_csv("EdStatsCountry.csv")

# %% [markdown]
# # nettoyage des données

# %%
EdStatsData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %%
EdStatsData.describe(include='all')
# Out:
#        Country Name Country Code  \
# count        886930       886930
# unique          242          242
# top         Moldova          AND
# freq           3665         3665
# mean            NaN          NaN
# std             NaN          NaN
# min             NaN          NaN
# 25%             NaN          NaN
# 50%             NaN          NaN
# 75%             NaN          NaN
# max             NaN          NaN
#
#                                            Indicator Name     Indicator Code  \
# count                                              886930             886930
# unique                                               3665               3665
# top     Wittgenstein Projection: Percentage of the pop...  PRJ.ATT.2039.1.MA
# freq                                                  242                242
# mean                                                  NaN                NaN
# std                                                   NaN                NaN
# ...

# %%
# on garde que les annees 2000 a 2015
annee = [str(i) for i in np.arange(2000, 2016, 1)]
EdColumns=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code']+annee
EdStatsData_nettoye = EdStatsData.loc[:,EdColumns]
EdStatsData_nettoye.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 20 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   2000            176676 non-null  float64
#  5   2001            123509 non-null  float64
#  6   2002            124205 non-null  float64
#  7   2003            130363 non-null  float64
#  8   2004            128814 non-null  float64
#  9   2005            184108 non-null  float64
#  10  2006            140312 non-null  float64
#  11  2007            137272 non-null  float64
#  12  2008            134387 non-null  float64
#  13  2009            142108 non-null  float64
#  14  2010            242442 non-null  float64
#  15  2011            146012 non-null  float64
# ...

# %%
# on effface les lignes vides
EdStatsData_nettoye = EdStatsData_nettoye.dropna(how = 'all', subset = annee)
EdStatsData_nettoye.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 348113 entries, 4 to 886929
# Data columns (total 20 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    348113 non-null  object
#  1   Country Code    348113 non-null  object
#  2   Indicator Name  348113 non-null  object
#  3   Indicator Code  348113 non-null  object
#  4   2000            176676 non-null  float64
#  5   2001            123509 non-null  float64
#  6   2002            124205 non-null  float64
#  7   2003            130363 non-null  float64
#  8   2004            128814 non-null  float64
#  9   2005            184108 non-null  float64
#  10  2006            140312 non-null  float64
#  11  2007            137272 non-null  float64
#  12  2008            134387 non-null  float64
#  13  2009            142108 non-null  float64
#  14  2010            242442 non-null  float64
#  15  2011            146012 non-null  float64
# ...

# %%
# au moins huit valeurs renseignes dans les anneees
EdStatsData_nettoye = EdStatsData_nettoye.dropna(thresh = 5, subset = annee)
EdStatsData_nettoye.info()

# %%
EdStatsData_nettoye.sample(10)
# Out:
#               Country Name Country Code  \
# 418938           Indonesia          IDN
# 421828  Iran, Islamic Rep.          IRN
# 576541          Montenegro          MNE
# 768391               Sudan          SDN
# 299485  Dominican Republic          DOM
# 704922              Serbia          SRB
# 654368                Peru          PER
# 772189            Suriname          SUR
# 267498       Cote d'Ivoire          CIV
# 682005              Rwanda          RWA
#
#                                            Indicator Name  \
# 418938  Enrolment in early childhood educational devel...
# 421828  Barro-Lee: Percentage of female population age...
# 576541  Enrolment in Grade 1 of primary education, fem...
# 768391                           Population, age 5, total
# 299485  Repetition rate in Grade 4 of primary educatio...
# 704922           GDP at market prices (constant 2005 US$)
# 654368  Percentage of repeaters in Grade 6 of primary ...
# ...

# %% [markdown]
# # recherche indicateur

# %%
EdStatsData_nettoyeFrance=EdStatsData_nettoye.loc[EdStatsData_nettoye['Country Name']=='France']
EdStatsData_nettoyeFrance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1860 entries, 337180 to 340836
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    1860 non-null   object
#  1   Country Code    1860 non-null   object
#  2   Indicator Name  1860 non-null   object
#  3   Indicator Code  1860 non-null   object
#  4   2000            1123 non-null   float64
#  5   2001            674 non-null    float64
#  6   2002            699 non-null    float64
#  7   2003            787 non-null    float64
#  8   2004            741 non-null    float64
#  9   2005            1090 non-null   float64
#  10  2006            888 non-null    float64
#  11  2007            836 non-null    float64
#  12  2008            838 non-null    float64
#  13  2009            938 non-null    float64
#  14  2010            1465 non-null   float64
#  15  2011            822 non-null    float64
# ...

# %%
pd.set_option('display.max_columns', None ) #pour afficher toutes les colonnes
pd.set_option('display.max_rows', 5 ) #pour afficher toutes les lignes
pd.set_option('max_colwidth', None)
pd.set_option('precision', 2)
EdStatsData_nettoyeFrance[EdStatsData_nettoyeFrance['Indicator Name'].str.contains('opulation', regex=False)]
# Out:
#        Country Name Country Code  \
# 337449       France          FRA
# 337450       France          FRA
# ...             ...          ...
# 340835       France          FRA
# 340836       France          FRA
#
#                                                                                                              Indicator Name  \
# 337449                                                 Barro-Lee: Percentage of female population age 15+ with no education
# 337450                         Barro-Lee: Percentage of female population age 15+ with primary schooling. Completed Primary
# ...                                                                                                                     ...
# 340835   Wittgenstein Projection: Population in thousands by highest level of educational attainment. Upper Secondary. Male
# 340836  Wittgenstein Projection: Population in thousands by highest level of educational attainment. Upper Secondary. Total
#
# ...

# %%
pd.set_option('display.max_rows', 10 ) #pour afficher toutes les lignes
EdStatsData_nettoye[EdStatsData_nettoye['Indicator Code'] == 'SP.POP.TOTL']
# Out:
#                                        Country Name Country Code  \
# 2533                                     Arab World          ARB
# 6198                            East Asia & Pacific          EAS
# 9863    East Asia & Pacific (excluding high income)          EAP
# 13528                                     Euro area          EMU
# 17193                         Europe & Central Asia          ECS
# ...                                             ...          ...
# 871138                        Virgin Islands (U.S.)          VIR
# 874803                           West Bank and Gaza          PSE
# 878468                                  Yemen, Rep.          YEM
# 882133                                       Zambia          ZMB
# 885798                                     Zimbabwe          ZWE
#
#            Indicator Name Indicator Code      2000      2001      2002  \
# 2533    Population, total    SP.POP.TOTL  2.78e+08  2.83e+08  2.90e+08
# ...

# %% [markdown]
# # indicateur choisi

# %%
indicateurs = ['UIS.E.5.B', 'UIS.E.3', 'NY.GDP.PCAP.PP.KD', 'SE.TER.ENRR', 'SE.SEC.ENRR.UP', 'IT.NET.USER.P2', 'SP.POP.TOTL']
EdStatsData_nettoye = EdStatsData_nettoye[EdStatsData_nettoye['Indicator Code'].isin(indicateurs)]
EdStatsData_nettoye.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1526 entries, 1206 to 885798
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    1526 non-null   object
#  1   Country Code    1526 non-null   object
#  2   Indicator Name  1526 non-null   object
#  3   Indicator Code  1526 non-null   object
#  4   2000            1272 non-null   float64
#  5   2001            1276 non-null   float64
#  6   2002            1296 non-null   float64
#  7   2003            1288 non-null   float64
#  8   2004            1309 non-null   float64
#  9   2005            1303 non-null   float64
#  10  2006            1284 non-null   float64
#  11  2007            1302 non-null   float64
#  12  2008            1304 non-null   float64
#  13  2009            1310 non-null   float64
#  14  2010            1314 non-null   float64
#  15  2011            1334 non-null   float64
# ...

# %%
EdStatsData_nettoye.head(10)
# Out:
#              Country Name Country Code  \
# 1206           Arab World          ARB
# 1214           Arab World          ARB
# 1246           Arab World          ARB
# 1339           Arab World          ARB
# 1343           Arab World          ARB
# 1375           Arab World          ARB
# 2533           Arab World          ARB
# 4871  East Asia & Pacific          EAS
# 4879  East Asia & Pacific          EAS
# 4911  East Asia & Pacific          EAS
#
#                                                                 Indicator Name  \
# 1206  Enrolment in tertiary education, ISCED 5 programmes, both sexes (number)
# 1214               Enrolment in upper secondary education, both sexes (number)
# 1246                       GDP per capita, PPP (constant 2011 international $)
# 1339                           Gross enrolment ratio, tertiary, both sexes (%)
# 1343                    Gross enrolment ratio, upper secondary, both sexes (%)
# ...

# %%
def lastOK(liste):
    retour = ''
    for elt in liste:
        if pd.notna(elt):
            retour = elt
    return retour
        
EdStatsData_nettoye['annee_val'] = EdStatsData_nettoye.apply(lastOK, axis = 1)
EdStatsData_nettoye.head()
# Out:
#      Country Name Country Code  \
# 1206   Arab World          ARB
# 1214   Arab World          ARB
# 1246   Arab World          ARB
# 1339   Arab World          ARB
# 1343   Arab World          ARB
#
#                                                                 Indicator Name  \
# 1206  Enrolment in tertiary education, ISCED 5 programmes, both sexes (number)
# 1214               Enrolment in upper secondary education, both sexes (number)
# 1246                       GDP per capita, PPP (constant 2011 international $)
# 1339                           Gross enrolment ratio, tertiary, both sexes (%)
# 1343                    Gross enrolment ratio, upper secondary, both sexes (%)
#
#          Indicator Code      2000      2001      2002      2003      2004  \
# 1206          UIS.E.5.B  5.15e+05  5.00e+05  5.10e+05  5.68e+05  6.16e+05
# 1214            UIS.E.3  8.55e+06  9.10e+06  9.39e+06  1.02e+07  1.07e+07
# ...

# %%
pd.set_option('display.max_rows', 10 ) #pour afficher toutes les lignes
EnsemblePays=EdStatsCountry.loc[EdStatsCountry["Currency Unit"].isna(), "Country Code"]
print(EnsemblePays)
# Out:
# 5      ARB
# 57     EAP
# 58     EAS
# 59     ECA
# 60     ECS
#       ...
# 187    SAS
# 198    SSA
# 200    SSF
# 225    UMC
# 234    WLD
# Name: Country Code, Length: 26, dtype: object

# %%
EdStatsData_nettoye_global = EdStatsData_nettoye[EdStatsData_nettoye["Country Code"].isin(EnsemblePays) ]
EdStatsData_nettoye_Pays = EdStatsData_nettoye[~EdStatsData_nettoye["Country Code"].isin(EnsemblePays) ]

# %%
EdStatsData_nettoye_global.head()
# Out:
#      Country Name Country Code  \
# 1206   Arab World          ARB
# 1214   Arab World          ARB
# 1246   Arab World          ARB
# 1339   Arab World          ARB
# 1343   Arab World          ARB
#
#                                                                 Indicator Name  \
# 1206  Enrolment in tertiary education, ISCED 5 programmes, both sexes (number)
# 1214               Enrolment in upper secondary education, both sexes (number)
# 1246                       GDP per capita, PPP (constant 2011 international $)
# 1339                           Gross enrolment ratio, tertiary, both sexes (%)
# 1343                    Gross enrolment ratio, upper secondary, both sexes (%)
#
#          Indicator Code      2000      2001      2002      2003      2004  \
# 1206          UIS.E.5.B  5.15e+05  5.00e+05  5.10e+05  5.68e+05  6.16e+05
# 1214            UIS.E.3  8.55e+06  9.10e+06  9.39e+06  1.02e+07  1.07e+07
# ...

# %%
EdStatsData_nettoye_Pays.loc[(EdStatsData_nettoye_Pays['Country Name'] == 'Costa Rica')]
# Out:
#        Country Name Country Code  \
# 261421   Costa Rica          CRI
# 261429   Costa Rica          CRI
# 261461   Costa Rica          CRI
# 261554   Costa Rica          CRI
# 261558   Costa Rica          CRI
# 261590   Costa Rica          CRI
# 262748   Costa Rica          CRI
#
#                                                                   Indicator Name  \
# 261421  Enrolment in tertiary education, ISCED 5 programmes, both sexes (number)
# 261429               Enrolment in upper secondary education, both sexes (number)
# 261461                       GDP per capita, PPP (constant 2011 international $)
# 261554                           Gross enrolment ratio, tertiary, both sexes (%)
# 261558                    Gross enrolment ratio, upper secondary, both sexes (%)
# 261590                                           Internet users (per 100 people)
# 262748                                                         Population, total
#
# ...

# %%
EdStatsData_indicateur_pays = EdStatsData_nettoye_Pays.pivot(index='Country Name',columns='Indicator Code',values='annee_val')
EdStatsData_indicateur_global = EdStatsData_nettoye_global.pivot(index='Country Name',columns='Indicator Code',values='annee_val')
EdStatsData_indicateur_pays.sample(50)
# Out:
# Indicator Code            IT.NET.USER.P2  NY.GDP.PCAP.PP.KD  SE.SEC.ENRR.UP  \
# Country Name
# Oman                               66.13           40138.95           96.36
# Bermuda                            98.32           50669.31           67.57
# Kiribati                           13.00            1967.30           74.35
# Sweden                             90.61           45679.28          163.63
# Suriname                           42.76           14766.80           54.19
# ...                                  ...                ...             ...
# Guinea                              8.20            1753.06           30.72
# Timor-Leste                        23.00            1920.15           65.07
# Sudan                              26.61            4290.37           34.84
# Turks and Caicos Islands             NaN                NaN             NaN
# Bahrain                            93.48           43926.47          102.82
#
# ...

# %%
EdStatsData_indicateur_pays.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 216 entries, Afghanistan to Zimbabwe
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   IT.NET.USER.P2     205 non-null    float64
#  1   NY.GDP.PCAP.PP.KD  192 non-null    float64
#  2   SE.SEC.ENRR.UP     191 non-null    float64
#  3   SE.TER.ENRR        185 non-null    float64
#  4   SP.POP.TOTL        215 non-null    float64
#  5   UIS.E.3            199 non-null    float64
#  6   UIS.E.5.B          162 non-null    float64
# dtypes: float64(7)
# memory usage: 13.5+ KB

# %%
pd.set_option('float_format', '{:f}'.format)
EdStatsData_indicateur_pays["SP.POP.TOTL"].describe()
# Out:
# count          215.000000
# mean      34096527.770614
# std      133896129.786585
# min          11001.000000
# 25%         839767.500000
# 50%        6234955.000000
# 75%       22971497.000000
# max     1371220000.000000
# Name: SP.POP.TOTL, dtype: float64

# %%
sns.boxplot(data = EdStatsData_indicateur_pays)
plt.xticks(rotation = 'vertical') 
plt.show()

# %%
sns.boxplot(data = EdStatsData_indicateur_pays.drop(['SP.POP.TOTL', 'UIS.E.3', 'UIS.E.5.B'], axis =1))
plt.xticks(rotation = 'vertical') 
plt.show()

# %%
pd.set_option('display.max_rows', 25 ) #pour afficher toutes les lignes
EdStatsData_indicateur_pays.loc[EdStatsData_indicateur_pays["SP.POP.TOTL"] > 500000000, "SP.POP.TOTL"]
# Out:
# Country Name
# China   1371220000.000000
# India   1309053980.000000
# Name: SP.POP.TOTL, dtype: float64

# %%
plt.rcParams["figure.figsize"] = [16, 16]
plt.subplot(421)
plt.title('UIS.E.5.B')
sns.boxplot(data = EdStatsData_indicateur_pays['UIS.E.5.B'])
plt.subplot(422)
plt.title('UIS.E.3')
sns.boxplot(data = EdStatsData_indicateur_pays['UIS.E.3'])
plt.subplot(423)
plt.title('NY.GDP.PCAP.PP.KD')
sns.boxplot(data = EdStatsData_indicateur_pays['NY.GDP.PCAP.PP.KD'])
plt.subplot(424)
plt.title('SE.TER.ENRR')
sns.boxplot(data = EdStatsData_indicateur_pays['SE.TER.ENRR'])
plt.subplot(425)
plt.title('SE.SEC.ENRR.UP')
sns.boxplot(data = EdStatsData_indicateur_pays['SE.SEC.ENRR.UP'])
plt.subplot(426)
plt.title('IT.NET.USER.P2')
sns.boxplot(data = EdStatsData_indicateur_pays['IT.NET.USER.P2'])
plt.subplot(427)
plt.title('SP.POP.TOTL')
sns.boxplot(data = EdStatsData_indicateur_pays['SP.POP.TOTL'])
plt.tight_layout()
plt.draw()

# %%
EdStatsData_indicateur_pays['UIS.E.5.B'].describe()
# Out:
# count        162.000000
# mean      262139.052149
# std      1528046.676622
# min           21.000000
# 25%         2603.750000
# 50%        14685.000000
# 75%        70728.750000
# max     17937696.000000
# Name: UIS.E.5.B, dtype: float64

# %%
EdStatsData_indicateur_pays['SP.POP.TOTL'].describe()
# Out:
# count          215.000000
# mean      34096527.770614
# std      133896129.786585
# min          11001.000000
# 25%         839767.500000
# 50%        6234955.000000
# 75%       22971497.000000
# max     1371220000.000000
# Name: SP.POP.TOTL, dtype: float64

# %%
EdStatsData_indicateur_pays = EdStatsData_indicateur_pays[EdStatsData_indicateur_pays['SP.POP.TOTL']>2000000]
EdStatsData_indicateur_pays['SP.POP.TOTL'].describe()
# Out:
# count          146.000000
# mean      49980042.881384
# std      160211835.469417
# min        2063531.000000
# 25%        5988183.750000
# 50%       12999831.000000
# 75%       36048889.250000
# max     1371220000.000000
# Name: SP.POP.TOTL, dtype: float64

# %%
EdStatsData_indicateur_pays['NY.GDP.PCAP.PP.KD'].describe()
# Out:
# count      141.000000
# mean     17810.797824
# std      19315.918750
# min        626.410873
# 25%       3601.614350
# 50%      11061.843585
# 75%      25034.450731
# max     119749.428536
# Name: NY.GDP.PCAP.PP.KD, dtype: float64

# %%
EdStatsData_indicateur_pays = EdStatsData_indicateur_pays[EdStatsData_indicateur_pays['NY.GDP.PCAP.PP.KD']>10000]
EdStatsData_indicateur_pays['NY.GDP.PCAP.PP.KD'].describe()
# Out:
# count       77.000000
# mean     29420.051287
# std      19525.752509
# min      10095.610168
# 25%      14914.206746
# 50%      24124.332364
# 75%      38885.895759
# max     119749.428536
# Name: NY.GDP.PCAP.PP.KD, dtype: float64

# %%
EdStatsData_indicateur_pays['IT.NET.USER.P2'].describe()
# Out:
# count   77.000000
# mean    66.261616
# std     20.148248
# min     14.996775
# 25%     55.763200
# 50%     69.616236
# 75%     80.122400
# max     96.810300
# Name: IT.NET.USER.P2, dtype: float64

# %%
EdStatsData_indicateur_pays = EdStatsData_indicateur_pays[EdStatsData_indicateur_pays['IT.NET.USER.P2']>60]
EdStatsData_indicateur_pays['IT.NET.USER.P2'].describe()
# Out:
# count   51.000000
# mean    77.995971
# std      9.873275
# min     61.869248
# 25%     69.709668
# 50%     77.352090
# 75%     86.950594
# max     96.810300
# Name: IT.NET.USER.P2, dtype: float64

# %%
plt.rcParams["figure.figsize"] = [16, 16]
plt.subplot(421)
plt.title('UIS.E.5.B')
sns.boxplot(data = EdStatsData_indicateur_pays['UIS.E.5.B'])
plt.subplot(422)
plt.title('UIS.E.3')
sns.boxplot(data = EdStatsData_indicateur_pays['UIS.E.3'])
plt.subplot(423)
plt.title('NY.GDP.PCAP.PP.KD')
sns.boxplot(data = EdStatsData_indicateur_pays['NY.GDP.PCAP.PP.KD'])
plt.subplot(424)
plt.title('SE.TER.ENRR')
sns.boxplot(data = EdStatsData_indicateur_pays['SE.TER.ENRR'])
plt.subplot(425)
plt.title('SE.SEC.ENRR.UP')
sns.boxplot(data = EdStatsData_indicateur_pays['SE.SEC.ENRR.UP'])
plt.subplot(426)
plt.title('IT.NET.USER.P2')
sns.boxplot(data = EdStatsData_indicateur_pays['IT.NET.USER.P2'])
plt.subplot(427)
plt.title('SP.POP.TOTL')
sns.boxplot(data = EdStatsData_indicateur_pays['SP.POP.TOTL'])
plt.tight_layout()
plt.draw()

# %%
pd.set_option('display.max_rows', 100 ) #pour afficher toutes les lignes
EdStatsData_indicateur_global.sort_values(by = ["SE.SEC.ENRR.UP","SE.TER.ENRR"])
# Out:
# Indicator Code                                      IT.NET.USER.P2  \
# Country Name
# Low income                                               10.246686
# Heavily indebted poor countries (HIPC)                   13.142045
# Least developed countries: UN classification             13.024301
# Sub-Saharan Africa (excluding high income)               17.752170
# Sub-Saharan Africa                                       17.755638
# South Asia                                               23.188901
# Arab World                                               36.868602
# Lower middle income                                      26.821998
# Low & middle income                                      36.070306
# Middle East & North Africa (excluding high income)       39.010070
# Middle East & North Africa                               44.231819
# Middle income                                            38.899744
# World                                                    43.198456
# ...

# %%
pd.set_option('display.max_rows', 100 ) #pour afficher toutes les lignes
EdStatsData_indicateur_pays
# Out:
# Indicator Code          IT.NET.USER.P2  NY.GDP.PCAP.PP.KD  SE.SEC.ENRR.UP  \
# Country Name
# Albania                      63.252933       10971.223704       89.460274
# Argentina                    68.043064       19101.297392       85.232620
# Australia                    84.560519       43832.426221      186.427887
# Austria                      83.940142       44288.928746       99.619698
# Azerbaijan                   77.000000       16698.863653             NaN
# Belarus                      67.300000       17229.555190      119.316940
# Belgium                      85.052900       41722.921863      158.077530
# Bosnia and Herzegovina       65.065503       10931.976105             NaN
# Canada                       88.470000       42983.100056      119.053093
# Chile                        64.289000       22536.617688       99.618759
# Croatia                      69.803100       20758.919322       92.947830
# ...

# %%
EdStatsData_indicateur_pays['SE.SEC.ENRR.UP'].fillna( value = EdStatsData_indicateur_pays['SE.SEC.ENRR.UP'].mean() , inplace = True)
EdStatsData_indicateur_pays['SE.TER.ENRR'].fillna( value = EdStatsData_indicateur_pays['SE.TER.ENRR'].mean() , inplace = True)
EdStatsData_indicateur_pays['UIS.E.5.B'].fillna( value = EdStatsData_indicateur_pays['UIS.E.5.B'].mean() , inplace = True)
EdStatsData_indicateur_pays
# Out:
# Indicator Code        IT.NET.USER.P2  NY.GDP.PCAP.PP.KD  SE.SEC.ENRR.UP  \
# Country Name
# Albania                    63.252933       10971.223704       89.460274
# Argentina                  68.043064       19101.297392       85.232620
# Australia                  84.560519       43832.426221      186.427887
# Austria                    83.940142       44288.928746       99.619698
# Azerbaijan                 77.000000       16698.863653      110.194662
# ...                              ...                ...             ...
# United Arab Emirates       90.500000       65975.375547      110.194662
# United Kingdom             92.000300       38839.166957      138.235916
# United States              74.554202       52926.544912       93.286598
# Uruguay                    64.600000       19831.445894       80.906548
# Venezuela, RB              61.869248       16745.021980       78.629623
#
# Indicator Code        SE.TER.ENRR      SP.POP.TOTL         UIS.E.3  \
# Country Name
# ...

# %%
plt.rcParams["figure.figsize"] = [16, 16]
plt.subplot(221)
plt.title('SE.SEC.ENRR.UP')
EdStatsData_indicateur_pays = EdStatsData_indicateur_pays.sort_values(by = 'SE.SEC.ENRR.UP', ascending = False)
EdStatsData_indicateur_pays['SE.SEC.ENRR.UP'].plot( kind = 'bar')
plt.subplot(222)
plt.title('SE.TER.ENRR')
EdStatsData_indicateur_pays = EdStatsData_indicateur_pays.sort_values(by = 'SE.TER.ENRR', ascending = False)
EdStatsData_indicateur_pays['SE.TER.ENRR'].plot( kind = 'bar')
plt.subplot(223)
plt.title('UIS.E.3')
EdStatsData_indicateur_pays = EdStatsData_indicateur_pays.sort_values(by = 'UIS.E.3', ascending = False)
EdStatsData_indicateur_pays['UIS.E.3'].plot( kind = 'bar')
plt.subplot(224)
plt.title('UIS.E.5.B')
EdStatsData_indicateur_pays = EdStatsData_indicateur_pays.sort_values(by = 'UIS.E.5.B', ascending = False)
EdStatsData_indicateur_pays['UIS.E.5.B'].plot( kind = 'bar')
plt.tight_layout()
plt.savefig('EdStatsData_indicateur_pays.png')
plt.draw()

# %%
colonneTri = [i for i in range(1,52)]
EdStatsData_indicateur_pays = EdStatsData_indicateur_pays.sort_values(by = 'SE.SEC.ENRR.UP', ascending = False)
EdStatsData_indicateur_pays['score'] = colonneTri
EdStatsData_indicateur_pays = EdStatsData_indicateur_pays.sort_values(by = 'SE.TER.ENRR', ascending = False)
EdStatsData_indicateur_pays['score'] += colonneTri
EdStatsData_indicateur_pays = EdStatsData_indicateur_pays.sort_values(by = 'UIS.E.3', ascending = False)
EdStatsData_indicateur_pays['score'] += colonneTri
EdStatsData_indicateur_pays = EdStatsData_indicateur_pays.sort_values(by = 'UIS.E.5.B', ascending = False)
EdStatsData_indicateur_pays['score'] += colonneTri
EdStatsData_indicateur_pays = EdStatsData_indicateur_pays.sort_values(by = 'score', ascending = True)
EdStatsData_indicateur_pays
EdStatsData_paysChoisi=EdStatsData_indicateur_pays.index[:16]
EdStatsData_paysChoisi
# Out:
# Index(['Spain', 'Australia', 'Russian Federation', 'United States',
#        'Korea, Rep.', 'France', 'Greece', 'United Kingdom', 'Chile',
#        'Argentina', 'Japan', 'Belgium', 'Belarus', 'Canada', 'New Zealand',
#        'Denmark'],
#       dtype='object', name='Country Name')

# %%
EdStatsData_paysChoisi = EdStatsData_paysChoisi.to_list()

# %%
EdStatsData_indicateur_global
# Out:
# Indicator Code                               IT.NET.USER.P2  \
# Country Name
# Arab World                                        36.868602
# East Asia & Pacific                               49.787924
# East Asia & Pacific (excluding high income)       45.210103
# Euro area                                         78.666346
# Europe & Central Asia                             71.162003
# ...                                                     ...
# South Asia                                        23.188901
# Sub-Saharan Africa                                17.755638
# Sub-Saharan Africa (excluding high income)        17.752170
# Upper middle income                               52.568863
# World                                             43.198456
#
# Indicator Code                               NY.GDP.PCAP.PP.KD  \
# Country Name
# Arab World                                        15454.968241
# East Asia & Pacific                               15142.564079
# ...

# %%
EdStatsData_indicateur_global=EdStatsData_indicateur_global[~EdStatsData_indicateur_global.index.str.contains('income', regex=False)]
EdStatsData_indicateur_global = EdStatsData_indicateur_global.iloc[[0,1,2,3,4,6,8,10,12,13],:]
EdStatsData_indicateur_global
# Out:
# Indicator Code              IT.NET.USER.P2  NY.GDP.PCAP.PP.KD  SE.SEC.ENRR.UP  \
# Country Name
# Arab World                       36.868602       15454.968241       55.596981
# East Asia & Pacific              49.787924       15142.564079       79.549347
# Euro area                        78.666346       37799.247340      113.228577
# Europe & Central Asia            71.162003       28801.644002      108.247787
# European Union                   75.497623       34381.179099      117.241722
# Latin America & Caribbean        54.279733       14504.155939       80.043221
# Middle East & North Africa       44.231819       17476.917757       66.641861
# North America                    75.941036       51927.560332       95.640877
# South Asia                       23.188901        5329.503739       52.375381
# Sub-Saharan Africa               17.755638        3493.572664       35.099972
#
# Indicator Code              SE.TER.ENRR       SP.POP.TOTL         UIS.E.3  \
# Country Name
# ...

# %%
plt.rcParams["figure.figsize"] = [16, 16]
plt.subplot(221)
plt.title('SE.SEC.ENRR.UP')
EdStatsData_indicateur_global = EdStatsData_indicateur_global.sort_values(by = 'SE.SEC.ENRR.UP', ascending = False)
EdStatsData_indicateur_global['SE.SEC.ENRR.UP'].plot( kind = 'bar')
plt.subplot(222)
plt.title('SE.TER.ENRR')
EdStatsData_indicateur_global = EdStatsData_indicateur_global.sort_values(by = 'SE.TER.ENRR', ascending = False)
EdStatsData_indicateur_global['SE.TER.ENRR'].plot( kind = 'bar')
plt.subplot(223)
plt.title('UIS.E.3')
EdStatsData_indicateur_global = EdStatsData_indicateur_global.sort_values(by = 'UIS.E.3', ascending = False)
EdStatsData_indicateur_global['UIS.E.3'].plot( kind = 'bar')
plt.subplot(224)
plt.title('UIS.E.5.B')
EdStatsData_indicateur_global = EdStatsData_indicateur_global.sort_values(by = 'UIS.E.5.B', ascending = False)
EdStatsData_indicateur_global['UIS.E.5.B'].plot( kind = 'bar')
plt.tight_layout()
plt.savefig('EdStatsData_indicateur_global.png')
plt.draw()

# %%
colonneTri = [i for i in range(1,11)]
EdStatsData_indicateur_global = EdStatsData_indicateur_global.sort_values(by = 'SE.SEC.ENRR.UP', ascending = False)
EdStatsData_indicateur_global['score'] = colonneTri
EdStatsData_indicateur_global = EdStatsData_indicateur_global.sort_values(by = 'SE.TER.ENRR', ascending = False)
EdStatsData_indicateur_global['score'] += colonneTri
EdStatsData_indicateur_global = EdStatsData_indicateur_global.sort_values(by = 'UIS.E.3', ascending = False)
EdStatsData_indicateur_global['score'] += colonneTri
EdStatsData_indicateur_global = EdStatsData_indicateur_global.sort_values(by = 'UIS.E.5.B', ascending = False)
EdStatsData_indicateur_global['score'] += colonneTri
EdStatsData_indicateur_global = EdStatsData_indicateur_global.sort_values(by = 'score', ascending = True)
EdStatsData_indicateur_global
# Out:
# Indicator Code              IT.NET.USER.P2  NY.GDP.PCAP.PP.KD  SE.SEC.ENRR.UP  \
# Country Name
# Europe & Central Asia            71.162003       28801.644002      108.247787
# East Asia & Pacific              49.787924       15142.564079       79.549347
# North America                    75.941036       51927.560332       95.640877
# European Union                   75.497623       34381.179099      117.241722
# Latin America & Caribbean        54.279733       14504.155939       80.043221
# Euro area                        78.666346       37799.247340      113.228577
# Middle East & North Africa       44.231819       17476.917757       66.641861
# South Asia                       23.188901        5329.503739       52.375381
# Sub-Saharan Africa               17.755638        3493.572664       35.099972
# Arab World                       36.868602       15454.968241       55.596981
#
# Indicator Code              SE.TER.ENRR       SP.POP.TOTL         UIS.E.3  \
# Country Name
# ...

# %%
pd.set_option('display.max_rows', None ) #pour afficher toutes les lignes
EdStatsData_paysChoisi.append('China')
EdStatsData_paysChoisi.append('India')
len(EdStatsData_paysChoisi)
EdStatsData_Choisi = EdStatsData_nettoye[EdStatsData_nettoye['Country Name'].isin(EdStatsData_paysChoisi)]
EdStatsData_Choisi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 125 entries, 118486 to 849148
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    125 non-null    object
#  1   Country Code    125 non-null    object
#  2   Indicator Name  125 non-null    object
#  3   Indicator Code  125 non-null    object
#  4   2000            121 non-null    float64
#  5   2001            113 non-null    float64
#  6   2002            115 non-null    float64
#  7   2003            117 non-null    float64
#  8   2004            115 non-null    float64
#  9   2005            118 non-null    float64
#  10  2006            121 non-null    float64
#  11  2007            121 non-null    float64
#  12  2008            117 non-null    float64
#  13  2009            117 non-null    float64
#  14  2010            119 non-null    float64
#  15  2011            123 non-null    float64
# ...

# %%
# 'SE.SEC.ENRR.UP', 'SE.TER.ENRR', 'UIS.E.3', 'UIS.E.5.B'
plt.rcParams["figure.figsize"] = [40, 16]
plt.rcParams["xtick.labelsize"] = 25
plt.rcParams["axes.titlesize"] = 40
EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'SE.SEC.ENRR.UP' ].set_index('Country Name').plot(kind='bar')
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'SE.TER.ENRR' ].set_index('Country Name').plot(kind='bar')
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'UIS.E.3' ].set_index('Country Name').plot(kind='bar')
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'UIS.E.5.B' ].set_index('Country Name').plot(kind='bar')
plt.xlabel("Pays")
plt.ylabel("Taux Scolarisation")
plt.title("Taux scolarisation dans l'enseignement secondaire superieur", y=1.05)
plt.show()

# %%
# 'SE.SEC.ENRR.UP', 'SE.TER.ENRR', 'UIS.E.3', 'UIS.E.5.B'
plt.rcParams["figure.figsize"] = [40, 16]
plt.rcParams["xtick.labelsize"] = 25
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'SE.SEC.ENRR.UP' ].set_index('Country Name').plot(kind='bar')
EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'SE.TER.ENRR' ].set_index('Country Name').plot(kind='bar')
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'UIS.E.3' ].set_index('Country Name').plot(kind='bar')
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'UIS.E.5.B' ].set_index('Country Name').plot(kind='bar')
plt.xlabel("Pays")
plt.ylabel("Taux Scolarisation")
plt.title("Taux scolarisation dans l'enseignement superieur", y=1.05)
plt.show()

# %%
# 'SE.SEC.ENRR.UP', 'SE.TER.ENRR', 'UIS.E.3', 'UIS.E.5.B'
plt.rcParams["figure.figsize"] = [40, 16]
plt.rcParams["xtick.labelsize"] = 25
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'SE.SEC.ENRR.UP' ].set_index('Country Name').plot(kind='bar')
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'SE.TER.ENRR' ].set_index('Country Name').plot(kind='bar')
EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'UIS.E.3' ].set_index('Country Name').plot(kind='bar')
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'UIS.E.5.B' ].set_index('Country Name').plot(kind='bar')
plt.xlabel("Pays")
plt.ylabel("Scolarisation")
plt.title("Scolarisation Brute dans l'enseignement secondaire superieure", y=1.05)
plt.show()

# %%
# 'SE.SEC.ENRR.UP', 'SE.TER.ENRR', 'UIS.E.3', 'UIS.E.5.B'
plt.rcParams["figure.figsize"] = [40, 16]
plt.rcParams["xtick.labelsize"] = 25
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'SE.SEC.ENRR.UP' ].set_index('Country Name').plot(kind='bar')
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'SE.TER.ENRR' ].set_index('Country Name').plot(kind='bar')
EdStatsData_Choisi[ ( EdStatsData_Choisi['Indicator Code'] == 'UIS.E.3' ) &  ~( EdStatsData_Choisi['Country Name'].isin( ['China', 'India', 'United States']) ) ].set_index('Country Name').plot(kind='bar')
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'UIS.E.5.B' ].set_index('Country Name').plot(kind='bar')
plt.xlabel("Pays")
plt.ylabel("Scolarisation")
plt.title("Scolarisation Brute dans l'enseignement secondaire superieure", y=1.05)
plt.show()

# %%
# 'SE.SEC.ENRR.UP', 'SE.TER.ENRR', 'UIS.E.3', 'UIS.E.5.B'
plt.rcParams["figure.figsize"] = [40, 16]
plt.rcParams["xtick.labelsize"] = 25
#dStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'SE.SEC.ENRR.UP' ].set_index('Country Name').plot(kind='bar')
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'SE.TER.ENRR' ].set_index('Country Name').plot(kind='bar')
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'UIS.E.3' ].set_index('Country Name').plot(kind='bar')
EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'UIS.E.5.B' ].set_index('Country Name').plot(kind='bar')
plt.xlabel("Pays")
plt.ylabel("Scolarisation")
plt.title("Scolarisation Brute dans l'enseignement superieur", y=1.05)
plt.show()

# %%
# 'SE.SEC.ENRR.UP', 'SE.TER.ENRR', 'UIS.E.3', 'UIS.E.5.B'
plt.rcParams["figure.figsize"] = [40, 16]
plt.rcParams["xtick.labelsize"] = 25
#dStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'SE.SEC.ENRR.UP' ].set_index('Country Name').plot(kind='bar')
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'SE.TER.ENRR' ].set_index('Country Name').plot(kind='bar')
#EdStatsData_Choisi[ EdStatsData_Choisi['Indicator Code'] == 'UIS.E.3' ].set_index('Country Name').plot(kind='bar')
EdStatsData_Choisi[ ( EdStatsData_Choisi['Indicator Code'] == 'UIS.E.5.B' ) &  ~( EdStatsData_Choisi['Country Name'].isin( ['China', 'India', 'United States']) ) ].set_index('Country Name').plot(kind='bar')
plt.xlabel("Pays")
plt.ylabel("Scolarisation")
plt.title("Scolarisation Brute dans l'enseignement superieur", y=1.05)
plt.show()
